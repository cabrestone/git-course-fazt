# %% [markdown]
# <a href="https://colab.research.google.com/github/cabrestone/git-course-fazt/blob/master/training_method_C_to_F_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np

# %%
celsius =np.array([-40,-11,0,8,15,23,38], dtype=float)
fahrenheit =np.array([-42,14,33,46,59,72,100], dtype=float)

# %%
capa = tf.keras.layers.Dense(units=1, input_shape=[1])
modelo = tf.keras.Sequential([capa])

# %%
modelo.compile(
    optimizer=tf.keras.optimizers.Adam(0.1),
    loss='mean_squared_error'
)

# %%
print("comenzando entrenamiento...")
historial = modelo.fit(celsius, fahrenheit,epochs=1000, verbose=False)
print('Modelo entrenado!')
# Out:
# comenzando entrenamiento...
# Modelo entrenado!

# %%
import matplotlib.pyplot as plt
plt.xlabel("# epoca")
plt.ylabel("magnitud de perdida")
plt.plot(historial.history["loss"])

# %%
print("hagamos una prediccion!")
resultado = modelo.predict([22])
print("el resultado es " + str(resultado)+ "fahrenheit!")
# Out:
# hagamos una prediccion!
# 1/1 [==============================] - 0s 61ms/step
# el resultado es [[71.44416]]fahrenheit!
